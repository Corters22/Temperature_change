# %%
import pandas as pd
import matplotlib as plot

# %%
filepath = "data/Environment_Temperature_change_E_All_Data_NOFLAG.csv"
full_data = pd.read_csv(filepath, encoding='latin-1')
full_data.head()
# Out:
#    Area Code         Area  Months Code    Months  Element Code  \
# 0          2  Afghanistan         7001   January          7271
# 1          2  Afghanistan         7001   January          6078
# 2          2  Afghanistan         7002  February          7271
# 3          2  Afghanistan         7002  February          6078
# 4          2  Afghanistan         7003     March          7271
#
#               Element Unit  Y1961  Y1962  Y1963  ...  Y2010  Y2011  Y2012  \
# 0  Temperature change   °C  0.777  0.062  2.744  ...  3.601  1.179 -0.583
# 1  Standard Deviation   °C  1.950  1.950  1.950  ...  1.950  1.950  1.950
# 2  Temperature change   °C -1.743  2.465  3.919  ...  1.212  0.321 -3.201
# 3  Standard Deviation   °C  2.597  2.597  2.597  ...  2.597  2.597  2.597
# 4  Temperature change   °C  0.516  1.336  0.403  ...  3.390  0.748 -0.527
#
#    Y2013  Y2014  Y2015  Y2016  Y2017  Y2018  Y2019
# 0  1.233  1.755  1.943  3.416  1.201  1.996  2.951
# ...

# %%
full_data.columns
full_data.columns = ['Area Code', 'Area', 'Months Code', 'Months', 'Element Code', 'Element',
       'Unit', '1961', '1962', '1963', '1964', '1965', '1966', '1967',
       '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
       '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
       '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
       '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
       '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
       '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
       '2016', '2017', '2018', '2019']

# %%
full_data = full_data[['Area', 'Months','Element', 'Unit', '1961', '1962', '1963', '1964', '1965', '1966', '1967',
       '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
       '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
       '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
       '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
       '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
       '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
       '2016', '2017', '2018', '2019']]
full_data.head()
# Out:
#           Area    Months             Element Unit   1961   1962   1963   1964  \
# 0  Afghanistan   January  Temperature change   °C  0.777  0.062  2.744 -5.232
# 1  Afghanistan   January  Standard Deviation   °C  1.950  1.950  1.950  1.950
# 2  Afghanistan  February  Temperature change   °C -1.743  2.465  3.919 -0.202
# 3  Afghanistan  February  Standard Deviation   °C  2.597  2.597  2.597  2.597
# 4  Afghanistan     March  Temperature change   °C  0.516  1.336  0.403  1.659
#
#     1965   1966  ...   2010   2011   2012   2013   2014   2015   2016   2017  \
# 0  1.868  3.629  ...  3.601  1.179 -0.583  1.233  1.755  1.943  3.416  1.201
# 1  1.950  1.950  ...  1.950  1.950  1.950  1.950  1.950  1.950  1.950  1.950
# 2 -0.096  3.397  ...  1.212  0.321 -3.201  1.494 -3.187  2.699  2.251 -0.323
# 3  2.597  2.597  ...  2.597  2.597  2.597  2.597  2.597  2.597  2.597  2.597
# 4 -0.909 -0.069  ...  3.390  0.748 -0.527  2.246 -0.076 -0.497  2.296  0.834
#
#     2018   2019
# 0  1.996  2.951
# ...

# %%
temp_change_df = full_data.loc[full_data.Element == "Temperature change"]
temp_change_df.head()
# Out:
#           Area    Months             Element Unit   1961   1962   1963   1964  \
# 0  Afghanistan   January  Temperature change   °C  0.777  0.062  2.744 -5.232
# 2  Afghanistan  February  Temperature change   °C -1.743  2.465  3.919 -0.202
# 4  Afghanistan     March  Temperature change   °C  0.516  1.336  0.403  1.659
# 6  Afghanistan     April  Temperature change   °C -1.709  0.117  0.919 -0.533
# 8  Afghanistan       May  Temperature change   °C  1.412 -0.092 -0.690 -0.160
#
#     1965   1966  ...   2010   2011   2012   2013   2014   2015   2016   2017  \
# 0  1.868  3.629  ...  3.601  1.179 -0.583  1.233  1.755  1.943  3.416  1.201
# 2 -0.096  3.397  ...  1.212  0.321 -3.201  1.494 -3.187  2.699  2.251 -0.323
# 4 -0.909 -0.069  ...  3.390  0.748 -0.527  2.246 -0.076 -0.497  2.296  0.834
# 6 -1.816 -1.192  ...  2.591  1.712  1.417 -0.052  0.585  1.589  0.980  1.252
# 8 -0.190 -0.192  ...  1.419  3.643  0.909  1.201  0.959  1.862  3.246  3.280
#
#     2018   2019
# 0  1.996  2.951
# ...

# %%
temp_change_df.to_json("data/temp_change.json")

# %%
std_df = full_data.loc[full_data.Element == "Standard Deviation"]
std_df.head()
# Out:
#           Area    Months             Element Unit   1961   1962   1963   1964  \
# 1  Afghanistan   January  Standard Deviation   °C  1.950  1.950  1.950  1.950
# 3  Afghanistan  February  Standard Deviation   °C  2.597  2.597  2.597  2.597
# 5  Afghanistan     March  Standard Deviation   °C  1.512  1.512  1.512  1.512
# 7  Afghanistan     April  Standard Deviation   °C  1.406  1.406  1.406  1.406
# 9  Afghanistan       May  Standard Deviation   °C  1.230  1.230  1.230  1.230
#
#     1965   1966  ...   2010   2011   2012   2013   2014   2015   2016   2017  \
# 1  1.950  1.950  ...  1.950  1.950  1.950  1.950  1.950  1.950  1.950  1.950
# 3  2.597  2.597  ...  2.597  2.597  2.597  2.597  2.597  2.597  2.597  2.597
# 5  1.512  1.512  ...  1.512  1.512  1.512  1.512  1.512  1.512  1.512  1.512
# 7  1.406  1.406  ...  1.406  1.406  1.406  1.406  1.406  1.406  1.406  1.406
# 9  1.230  1.230  ...  1.230  1.230  1.230  1.230  1.230  1.230  1.230  1.230
#
#     2018   2019
# 1  1.950  1.950
# ...

# %%
std_df.to_json("data/std.json")

# %%
usa_df = temp_change_df.loc[temp_change_df.Area == "United States of America"]
usa_df
# Out:
#                           Area               Months             Element Unit  \
# 7888  United States of America              January  Temperature change   °C
# 7890  United States of America             February  Temperature change   °C
# 7892  United States of America                March  Temperature change   °C
# 7894  United States of America                April  Temperature change   °C
# 7896  United States of America                  May  Temperature change   °C
# 7898  United States of America                 June  Temperature change   °C
# 7900  United States of America                 July  Temperature change   °C
# 7902  United States of America               August  Temperature change   °C
# 7904  United States of America            September  Temperature change   °C
# 7906  United States of America              October  Temperature change   °C
# 7908  United States of America             November  Temperature change   °C
# ...

# %%
usa_df.to_json("data/usa.json")
